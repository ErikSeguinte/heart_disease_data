# %% [markdown]
# # Read Data
# * Read terrible data file and turn it into a sane csv

# %%
def load_and_pickle():
    import pickle
    import os
    with open('new.data', 'r') as reader, open('new.csv', 'w') as writer:
        new_line = []
        for line in reader:
            cells = [cell.strip() for cell in line.split(' ')]
            new_line.extend(cells)
            if new_line[-1] == 'name':
                writer.write(','.join(new_line))
                writer.write('\n')
                new_line = []
            
    df = pd.read_csv('new.csv')
    df.to_pickle('new.pickle.xz')
    os.remove('new.csv')

# %%
load_and_pickle()

# %%
df = pd.read_pickle('new.pickle.xz')

# %%
df
# Out:
#        1  15943882  63  1.1  -9  -9.1  -9.2  -27  1.2  145  ...  -9.24  -9.25  \
# 0      2  15964847  67    1  -9    -9    -9  -27    4  160  ...     -9     -9
# 1      3  15952199  67    1  -9    -9    -9  -27    4  120  ...     -9     -9
# 2      4  15929464  37    1  -9    -9    -9  -27    3  130  ...     -9     -9
# 3      6  11961207  41    0  -9    -9    -9  -27    2  130  ...     -9     -9
# 4      7  15970464  56    1  -9    -9    -9  -27    2  120  ...     -9     -9
# ..   ...       ...  ..  ...  ..   ...   ...  ...  ...  ...  ...    ...    ...
# 297  315  17541960  45    1  -9    -9    -9  -27    1  110  ...     -9     -9
# 298  316  17541609  68    1  -9    -9    -9  -27    4  144  ...     -9     -9
# 299  317  17533380  57    1  -9    -9    -9  -27    4  130  ...     -9     -9
# 300  318  14640215  57    0  -9    -9    -9  -27    2  130  ...     -9     -9
# 301  319  17539736  38    1  -9    -9    -9  -27    3  138  ...     -9     -9
#
# ...
